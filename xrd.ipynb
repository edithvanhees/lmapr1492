# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.analysis.diffraction.xrd import XRDCalculator

# %%
with MPRester("7QuxsitdhRpT0oyz") as m:

    structure = m.get_structure_by_material_id("mp-23209")    
    
xrd_calc = XRDCalculator()
xrd_patt = xrd.get_pattern(structure)
xrd.show_plot(structure, two_theta_range=(0,40))

# %%
print("Premier pic")
print("Angle 2Θ :", xrd_patt.x[0])
print("Intensité :", xrd_patt.y[0])
print("Indices hkl :", xrd_patt.hkls[0])
print("d :", xrd_patt.d_hkls[0])
# Out:
# Premier pic
# Angle 2Θ : 21.84428587848926
# Intensité : 74.56031971949484
# Indices hkl : [{'hkl': (1, 1, 1), 'multiplicity': 2}, {'hkl': (1, 0, 0), 'multiplicity': 6}]
# d : 4.06871782814013

# %%
print("Deuxième pic")
print("Angle 2Θ :", xrd_patt.x[1])
print("Intensité :", xrd_patt.y[1])
print("Indices hkl :", xrd_patt.hkls[1])
print("d :", xrd_patt.d_hkls[1])
# Out:
# Deuxième pic
# Angle 2Θ : 25.275571416089672
# Intensité : 0.862293807008719
# Indices hkl : [{'hkl': (1, 1, 0), 'multiplicity': 6}]
# d : 3.523613

# %%
print("Troisième pic")
print("Angle 2Θ :", xrd_patt.x[2])
print("Intensité :", xrd_patt.y[2])
print("Indices hkl :", xrd_patt.hkls[2])
print("d :", xrd_patt.d_hkls[2])
# Out:
# Troisième pic
# Angle 2Θ : 36.04750711666948
# Intensité : 100.0
# Indices hkl : [{'hkl': (2, 1, 1), 'multiplicity': 6}, {'hkl': (1, 0, -1), 'multiplicity': 6}]
# d : 2.4915706465770744
